# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\spatr\anaconda3\lib\site-packages (25.3)

# %%
# !pip install spacy transformers scikit-learn keybert --timeout 120 --no-cache-dir
# Out:
# Requirement already satisfied: spacy in c:\users\spatr\anaconda3\lib\site-packages (3.8.11)
# Requirement already satisfied: transformers in c:\users\spatr\anaconda3\lib\site-packages (4.29.0)
# Requirement already satisfied: scikit-learn in c:\users\spatr\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: keybert in c:\users\spatr\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (0.21.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (4.66.5)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (2.12.0)
# Requirement already satisfied: jinja2 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\spatr\anaconda3\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\spatr\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\spatr\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.1)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\spatr\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\spatr\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\spatr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\spatr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\spatr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\spatr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\spatr\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\spatr\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\spatr\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\spatr\anaconda3\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\spatr\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\spatr\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (5.2.1)
# Requirement already satisfied: filelock in c:\users\spatr\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in c:\users\spatr\anaconda3\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\spatr\anaconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\spatr\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\spatr\anaconda3\lib\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\spatr\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2024.6.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\spatr\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\spatr\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\spatr\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: rich>=10.4.0 in c:\users\spatr\anaconda3\lib\site-packages (from keybert) (13.7.1)
# Requirement already satisfied: sentence-transformers>=0.3.8 in c:\users\spatr\anaconda3\lib\site-packages (from keybert) (2.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\spatr\anaconda3\lib\site-packages (from rich>=10.4.0->keybert) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\spatr\anaconda3\lib\site-packages (from rich>=10.4.0->keybert) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\spatr\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.0)
# Requirement already satisfied: torch>=1.6.0 in c:\users\spatr\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (2.4.1)
# Requirement already satisfied: torchvision in c:\users\spatr\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (0.19.1)
# Requirement already satisfied: nltk in c:\users\spatr\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (3.9.1)
# Requirement already satisfied: sentencepiece in c:\users\spatr\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (0.2.1)
# Requirement already satisfied: sympy in c:\users\spatr\anaconda3\lib\site-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.14.0)
# Requirement already satisfied: networkx in c:\users\spatr\anaconda3\lib\site-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\spatr\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\spatr\anaconda3\lib\site-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\spatr\anaconda3\lib\site-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (10.4.0)

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu --timeout 120
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in c:\users\spatr\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: torchvision in c:\users\spatr\anaconda3\lib\site-packages (0.19.1)
# Requirement already satisfied: torchaudio in c:\users\spatr\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: filelock in c:\users\spatr\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\spatr\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy in c:\users\spatr\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\spatr\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\spatr\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\spatr\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in c:\users\spatr\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\spatr\anaconda3\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\spatr\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\spatr\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 5.6 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.3/12.8 MB 4.8 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.6/12.8 MB 2.5 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.6/12.8 MB 2.5 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.6/12.8 MB 2.5 MB/s eta 0:00:05
#      ----- ---------------------------------- 1.8/12.8 MB 1.4 MB/s eta 0:00:08
#      ------ --------------------------------- 2.1/12.8 MB 1.5 MB/s eta 0:00:08
#      ------ --------------------------------- 2.1/12.8 MB 1.5 MB/s eta 0:00:08
#      ------ --------------------------------- 2.1/12.8 MB 1.5 MB/s eta 0:00:08
#      ------- -------------------------------- 2.4/12.8 MB 1.1 MB/s eta 0:00:10
#      ------- -------------------------------- 2.4/12.8 MB 1.1 MB/s eta 0:00:10
#      --------- ------------------------------ 3.1/12.8 MB 1.2 MB/s eta 0:00:08
#      ---------- ----------------------------- 3.4/12.8 MB 1.2 MB/s eta 0:00:08
#      ----------- ---------------------------- 3.7/12.8 MB 1.3 MB/s eta 0:00:08
#      ------------ --------------------------- 3.9/12.8 MB 1.2 MB/s eta 0:00:08
#      ------------- -------------------------- 4.2/12.8 MB 1.2 MB/s eta 0:00:07
#      ------------- -------------------------- 4.5/12.8 MB 1.2 MB/s eta 0:00:07
#      ------------- -------------------------- 4.5/12.8 MB 1.2 MB/s eta 0:00:07
#      -------------- ------------------------- 4.7/12.8 MB 1.2 MB/s eta 0:00:07
#      --------------- ------------------------ 5.0/12.8 MB 1.2 MB/s eta 0:00:07
#      ---------------- ----------------------- 5.2/12.8 MB 1.2 MB/s eta 0:00:07
#      ----------------- ---------------------- 5.5/12.8 MB 1.2 MB/s eta 0:00:07
#      ------------------ --------------------- 5.8/12.8 MB 1.2 MB/s eta 0:00:06
#      ------------------ --------------------- 6.0/12.8 MB 1.2 MB/s eta 0:00:06
#      ------------------- -------------------- 6.3/12.8 MB 1.2 MB/s eta 0:00:06
#      -------------------- ------------------- 6.6/12.8 MB 1.2 MB/s eta 0:00:06
#      --------------------- ------------------ 6.8/12.8 MB 1.2 MB/s eta 0:00:05
#      ---------------------- ----------------- 7.1/12.8 MB 1.2 MB/s eta 0:00:05
#      ---------------------- ----------------- 7.3/12.8 MB 1.2 MB/s eta 0:00:05
#      ---------------------- ----------------- 7.3/12.8 MB 1.2 MB/s eta 0:00:05
#      ---------------------- ----------------- 7.3/12.8 MB 1.2 MB/s eta 0:00:05
#      ---------------------- ----------------- 7.3/12.8 MB 1.2 MB/s eta 0:00:05
#      ----------------------- ---------------- 7.6/12.8 MB 1.1 MB/s eta 0:00:05
#      ------------------------ --------------- 7.9/12.8 MB 1.1 MB/s eta 0:00:05
#      -------------------------- ------------- 8.4/12.8 MB 1.1 MB/s eta 0:00:04
#      --------------------------- ------------ 8.7/12.8 MB 1.1 MB/s eta 0:00:04
#      --------------------------- ------------ 8.9/12.8 MB 1.1 MB/s eta 0:00:04
#      ---------------------------- ----------- 9.2/12.8 MB 1.1 MB/s eta 0:00:04
#      ----------------------------- ---------- 9.4/12.8 MB 1.1 MB/s eta 0:00:03
#      ------------------------------ --------- 9.7/12.8 MB 1.1 MB/s eta 0:00:03
#      ------------------------------ --------- 9.7/12.8 MB 1.1 MB/s eta 0:00:03
#      ------------------------------- -------- 10.0/12.8 MB 1.1 MB/s eta 0:00:03
#      ------------------------------- -------- 10.2/12.8 MB 1.1 MB/s eta 0:00:03
#      -------------------------------- ------- 10.5/12.8 MB 1.1 MB/s eta 0:00:03
#      --------------------------------- ------ 10.7/12.8 MB 1.1 MB/s eta 0:00:02
#      --------------------------------- ------ 10.7/12.8 MB 1.1 MB/s eta 0:00:02
#      --------------------------------- ------ 10.7/12.8 MB 1.1 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.0/12.8 MB 1.1 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.0/12.8 MB 1.1 MB/s eta 0:00:02
#      ----------------------------------- ---- 11.3/12.8 MB 1.1 MB/s eta 0:00:02
#      ----------------------------------- ---- 11.3/12.8 MB 1.1 MB/s eta 0:00:02
#      ------------------------------------ --- 11.5/12.8 MB 1.1 MB/s eta 0:00:02
#      ------------------------------------- -- 12.1/12.8 MB 1.1 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 1.1 MB/s  0:00:11
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !pip install -U huggingface_hub
# !pip install -U keybert
# Out:
# Requirement already satisfied: huggingface_hub in c:\users\spatr\anaconda3\lib\site-packages (0.36.0)
# Collecting huggingface_hub
#   Using cached huggingface_hub-1.2.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in c:\users\spatr\anaconda3\lib\site-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\spatr\anaconda3\lib\site-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\spatr\anaconda3\lib\site-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\spatr\anaconda3\lib\site-packages (from huggingface_hub) (0.27.2)
# Requirement already satisfied: packaging>=20.9 in c:\users\spatr\anaconda3\lib\site-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\spatr\anaconda3\lib\site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: shellingham in c:\users\spatr\anaconda3\lib\site-packages (from huggingface_hub) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\spatr\anaconda3\lib\site-packages (from huggingface_hub) (4.66.5)
# Requirement already satisfied: typer-slim in c:\users\spatr\anaconda3\lib\site-packages (from huggingface_hub) (0.21.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\spatr\anaconda3\lib\site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in c:\users\spatr\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.9.0)
# Requirement already satisfied: certifi in c:\users\spatr\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\spatr\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.2)
# Requirement already satisfied: idna in c:\users\spatr\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.7)
# Requirement already satisfied: sniffio in c:\users\spatr\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\spatr\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.14.0)
# Requirement already satisfied: colorama in c:\users\spatr\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\spatr\anaconda3\lib\site-packages (from typer-slim->huggingface_hub) (8.1.7)
# Using cached huggingface_hub-1.2.3-py3-none-any.whl (520 kB)
# Installing collected packages: huggingface_hub
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.36.0
#     Uninstalling huggingface-hub-0.36.0:
#       Successfully uninstalled huggingface-hub-0.36.0
# Successfully installed huggingface_hub-1.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 2.12.0 requires huggingface-hub<1.0.0,>=0.11.0, but you have huggingface-hub 1.2.3 which is incompatible.
# transformers 4.29.0 requires huggingface-hub<1.0,>=0.11.0, but you have huggingface-hub 1.2.3 which is incompatible.
# Requirement already satisfied: keybert in c:\users\spatr\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\spatr\anaconda3\lib\site-packages (from keybert) (1.26.4)
# Requirement already satisfied: rich>=10.4.0 in c:\users\spatr\anaconda3\lib\site-packages (from keybert) (13.7.1)
# Requirement already satisfied: scikit-learn>=0.22.2 in c:\users\spatr\anaconda3\lib\site-packages (from keybert) (1.5.1)
# Requirement already satisfied: sentence-transformers>=0.3.8 in c:\users\spatr\anaconda3\lib\site-packages (from keybert) (2.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\spatr\anaconda3\lib\site-packages (from rich>=10.4.0->keybert) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\spatr\anaconda3\lib\site-packages (from rich>=10.4.0->keybert) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\spatr\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\spatr\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->keybert) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\spatr\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->keybert) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\spatr\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->keybert) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\spatr\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (4.29.0)
# Requirement already satisfied: tqdm in c:\users\spatr\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (4.66.5)
# Requirement already satisfied: torch>=1.6.0 in c:\users\spatr\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (2.4.1)
# Requirement already satisfied: torchvision in c:\users\spatr\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (0.19.1)
# Requirement already satisfied: nltk in c:\users\spatr\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (3.9.1)
# Requirement already satisfied: sentencepiece in c:\users\spatr\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (0.2.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\spatr\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (1.2.3)
# Requirement already satisfied: filelock in c:\users\spatr\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.13.1)
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers>=0.3.8->keybert)
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\spatr\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\spatr\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\spatr\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2024.9.11)
# Requirement already satisfied: requests in c:\users\spatr\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2.32.5)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\spatr\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\spatr\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\spatr\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (4.15.0)
# Requirement already satisfied: sympy in c:\users\spatr\anaconda3\lib\site-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.14.0)
# Requirement already satisfied: networkx in c:\users\spatr\anaconda3\lib\site-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.3)
# Requirement already satisfied: jinja2 in c:\users\spatr\anaconda3\lib\site-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.1.4)
# Requirement already satisfied: colorama in c:\users\spatr\anaconda3\lib\site-packages (from tqdm->sentence-transformers>=0.3.8->keybert) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\spatr\anaconda3\lib\site-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (2.1.3)
# Requirement already satisfied: click in c:\users\spatr\anaconda3\lib\site-packages (from nltk->sentence-transformers>=0.3.8->keybert) (8.1.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\spatr\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\spatr\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\spatr\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\spatr\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\spatr\anaconda3\lib\site-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\spatr\anaconda3\lib\site-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (10.4.0)
# Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Installing collected packages: huggingface-hub
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.2.3
#     Uninstalling huggingface_hub-1.2.3:
#       Successfully uninstalled huggingface_hub-1.2.3
# Successfully installed huggingface-hub-0.36.0

# %%
import spacy
from collections import Counter

nlp = spacy.load("en_core_web_sm")

def extract_keywords_spacy(text, top_n=5):
    doc = nlp(text.lower())
    keywords = [
        token.lemma_
        for token in doc
        if token.pos_ in ["NOUN", "PROPN"]
        and not token.is_stop
        and token.is_alpha
    ]
    return Counter(keywords).most_common(top_n)

# %%
extract_keywords_spacy(
    "Medical NLP pipelines extract symptoms and diagnoses from clinical notes"
)
# Out:
# [('nlp', 1), ('pipeline', 1), ('symptom', 1), ('diagnosis', 1), ('note', 1)]

# %%
import spacy
from spacy.matcher import PhraseMatcher

nlp = spacy.load("en_core_web_sm")

MEDICAL_TERMS = {
    "SYMPTOM": [
        "neck pain", "back pain", "head impact",
        "stiffness", "discomfort"
    ],
    "DIAGNOSIS": [
        "whiplash injury"
    ],
    "TREATMENT": [
        "physiotherapy", "painkillers"
    ],
    "PROGNOSIS": [
        "full recovery", "no long-term damage"
    ]
}

def extract_medical_entities(text):
    matcher = PhraseMatcher(nlp.vocab, attr="LOWER")

    for label, terms in MEDICAL_TERMS.items():
        patterns = [nlp(term) for term in terms]
        matcher.add(label, patterns)

    doc = nlp(text)
    entities = {k: [] for k in MEDICAL_TERMS}

    for match_id, start, end in matcher(doc):
        label = nlp.vocab.strings[match_id]
        entities[label].append(doc[start:end].text)

    return entities

# %%
def generate_medical_summary(entities):
    summary = {
        "Patient_Name": "Janet Jones",  # From metadata / EHR
        "Symptoms": list(set(entities.get("SYMPTOM", []))),
        "Diagnosis": entities.get("DIAGNOSIS", ["Not mentioned"])[0],
        "Treatment": list(set(entities.get("TREATMENT", []))),
        "Current_Status": "Occasional back pain",
        "Prognosis": entities.get("PROGNOSIS", ["Not specified"])[0]
    }

    return summary

# %%
from transformers import pipeline

sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english",
    framework="pt"   # 🔥 THIS FIXES EVERYTHING
)

sentiment_pipeline("I love football analytics and AI!")
# Out:
# C:\Users\spatr\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Xformers is not installed correctly. If you want to use memorry_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# [{'label': 'POSITIVE', 'score': 0.9988646507263184}]

# %%
def detect_intent(text):
    text = text.lower()

    if any(word in text for word in ["worried", "concerned", "afraid"]):
        return "Seeking reassurance"

    if any(word in text for word in ["pain", "hurt", "ache"]):
        return "Reporting symptoms"

    if any(word in text for word in ["better", "recover", "okay"]):
        return "Confirming recovery"

    return "General inquiry"

# %%
# %%writefile medical_ner.py
import spacy

nlp = spacy.load("en_core_web_sm")

def extract_medical_entities(text):
    """
    Extract medical-related entities from text.
    Returns a dictionary grouped by entity label.
    """
    doc = nlp(text)

    entities = {}
    for ent in doc.ents:
        entities.setdefault(ent.label_, []).append(ent.text)

    return entities
# Out:
# Overwriting medical_ner.py

# %%
import medical_ner
print(dir(medical_ner))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'extract_medical_entities', 'nlp', 'spacy']

# %%
# %%writefile sentiment_intent.py
from transformers import pipeline

# Force PyTorch backend
sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english",
    framework="pt"
)

def classify_sentiment(text):
    """
    Classifies sentiment of the input text.
    Returns label and confidence score.
    """
    result = sentiment_pipeline(text)[0]
    return {
        "label": result["label"],
        "score": round(result["score"], 3)
    }
# Out:
# Overwriting sentiment_intent.py

# %%
# %%writefile intent_detection.py

def detect_intent(text):
    """
    Detects high-level intent from patient dialogue.
    Rule-based (simple & reliable for medical use).
    """

    text_lower = text.lower()

    if any(word in text_lower for word in ["pain", "hurt", "ache", "injury"]):
        return "Report_Symptom"

    if any(word in text_lower for word in ["worried", "anxious", "scared", "concerned"]):
        return "Express_Concern"

    if any(word in text_lower for word in ["treatment", "therapy", "physiotherapy", "medication"]):
        return "Discuss_Treatment"

    if any(word in text_lower for word in ["recover", "better", "improve", "heal"]):
        return "Prognosis_Inquiry"

    return "General_Information"
# Out:
# Overwriting intent_detection.py

# %%
from medical_ner import extract_medical_entities
from medical_summary import generate_medical_summary
from sentiment_intent import classify_sentiment
from intent_detection import detect_intent

TRANSCRIPT = """
I had a car accident. My neck and back hurt a lot for four weeks.
I had ten physiotherapy sessions, and now I only have occasional back pain.
"""

PATIENT_DIALOGUE = "I'm a bit worried about my back pain, but I hope it gets better soon."

def run_pipeline():
    entities = extract_medical_entities(TRANSCRIPT)
    summary = generate_medical_summary(entities)

    sentiment = classify_sentiment(PATIENT_DIALOGUE)
    intent = detect_intent(PATIENT_DIALOGUE)

    output = {
        **summary,
        "Sentiment": sentiment,
        "Intent": intent
    }

    return output


if __name__ == "__main__":
    import json
    print(json.dumps(run_pipeline(), indent=2))
# Out:
# C:\Users\spatr\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# {
#   "Patient_Name": "Janet Jones",
#   "Symptoms": [],
#   "Diagnosis": "Not mentioned",
#   "Treatment": [],
#   "Current_Status": "Occasional back pain",
#   "Prognosis": "Not specified",
#   "Sentiment": {
#     "label": "POSITIVE",
#     "score": 0.973
#   },
#   "Intent": "Report_Symptom"
# }

# %%
# %%writefile soap_note_generator.py

def generate_soap_note(entities, summary, sentiment, intent):
    """
    Generate a SOAP note from extracted NLP outputs.
    """

    soap_note = {
        "Subjective": {
            "Patient_Reported_Symptoms": summary.get("Symptoms", []),
            "Patient_Concerns": sentiment["label"],
            "Intent": intent
        },
        "Objective": {
            "Clinical_Findings": entities
        },
        "Assessment": {
            "Diagnosis": summary.get("Diagnosis", "Not mentioned"),
            "Current_Status": summary.get("Current_Status", "Not specified"),
            "Prognosis": summary.get("Prognosis", "Not specified")
        },
        "Plan": {
            "Treatment": summary.get("Treatment", []),
            "Follow_Up": "As advised by physician"
        }
    }

    return soap_note
# Out:
# Overwriting soap_note_generator.py

# %%
from soap_note_generator import generate_soap_note

# %%
from medical_ner import extract_medical_entities
from medical_summary import generate_medical_summary
from sentiment_intent import classify_sentiment
from intent_detection import detect_intent
from soap_note_generator import generate_soap_note

TRANSCRIPT = """
I had a car accident. My neck and back hurt a lot for four weeks.
I had ten physiotherapy sessions, and now I only have occasional back pain.
"""

PATIENT_DIALOGUE = "I'm a bit worried about my back pain, but I hope it gets better soon."

# 1️⃣ Extract entities
entities = extract_medical_entities(TRANSCRIPT)

# 2️⃣ Generate medical summary
summary = generate_medical_summary(entities)

# 3️⃣ Sentiment analysis
sentiment = classify_sentiment(PATIENT_DIALOGUE)

# 4️⃣ Intent detection
intent = detect_intent(PATIENT_DIALOGUE)

# 5️⃣ Generate SOAP note (CORRECT call)
soap_note = generate_soap_note(entities, summary, sentiment, intent)

import json
print(json.dumps(soap_note, indent=2))
# Out:
# {
#   "Subjective": {
#     "Patient_Reported_Symptoms": [],
#     "Patient_Concerns": "POSITIVE",
#     "Intent": "Report_Symptom"
#   },
#   "Objective": {
#     "Clinical_Findings": {
#       "DATE": [
#         "four weeks"
#       ],
#       "CARDINAL": [
#         "ten"
#       ]
#     }
#   },
#   "Assessment": {
#     "Diagnosis": "Not mentioned",
#     "Current_Status": "Occasional back pain",
#     "Prognosis": "Not specified"
#   },
#   "Plan": {
#     "Treatment": [],
#     "Follow_Up": "As advised by physician"
#   }
# }
